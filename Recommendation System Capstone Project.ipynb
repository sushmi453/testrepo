# %% [markdown]
# # Sentiment-based Product Recommendation System

# %% [markdown]
# ## Following tasks will be performed:
#
# 1. Data sourcing and sentiment analysis
# 2. Building a recommendation system
# 3.  Improving the recommendations using the sentiment analysis model
# 4.  Deploying the end-to-end project with a user interface

# %% [markdown]
# # Data sourcing and sentiment analysis
# ## In Sentiment Analysis, below steps need to be performed:
#
# Following eight major steps will be performed
#
# 1.  Data Sourcing/loading
#
# 2. Text preprocessing/Data cleaning
#
# 3. Exploratory data analysis (EDA)
#
# 4. Feature extraction
#
# 5. Model building using supervised learning
#
# 6. Model training and evaluation
#
# 7. Model inference

# %% [markdown]
# ## Import the required libraries.

# %%
#import the useful libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re, nltk, spacy, string
import en_core_web_sm
nlp = en_core_web_sm.load()
import matplotlib.pyplot as plt
from nltk.corpus import stopwords 
# %matplotlib inline

from scipy import stats
from scipy.interpolate import interp1d
from scipy.signal import correlate

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn import metrics
#import statsmodels.api as sm
#from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso, LogisticRegression
from sklearn import metrics
from imblearn.over_sampling import SMOTE
from collections import Counter
#import statsmodels
#import statsmodels.api as sm
#import statsmodels.formula.api as smf
# Libraries for text preprocessing and analysis
import re,nltk,spacy,string
nlp=spacy.load("en_core_web_sm")
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.decomposition import NMF
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS
#from scipy.signal._signaltools import _centered
from scipy.signal.signaltools import _centered
# Libraries for model evaluation metrics
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, f1_score, classification_report
from statsmodels.compat.numpy import lstsq

from plotly.offline import plot
import plotly.graph_objects as go
import plotly.express as px

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import classification_report,roc_auc_score,confusion_matrix,f1_score,precision_score,accuracy_score
from sklearn.metrics import pairwise_distances
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier 
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb

# Remove warnings
import warnings
warnings.filterwarnings('ignore')

# row/column display limit
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.options.mode.chained_assignment = None

# %%
df_review = pd.read_csv('sample30.csv')
print('Shape of dataset- ',df_review.shape)
df_review.head(5)
# Out:
# Shape of dataset-  (30000, 15)
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                                                                                                                                        categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Movie Bundles & Collections,CDs & Vinyl,Rap & Hip-Hop,Bass,Music on CD or Vinyl,Rap,Hip-Hop,Mainstream Rap,Pop Rap
# 1                                                                                    Food,Packaged Foods,Snacks,Crackers,Snacks, Cookies & Chips,Rice Cakes,Cakes
# 2                                                                                    Food,Packaged Foods,Snacks,Crackers,Snacks, Cookies & Chips,Rice Cakes,Cakes
# 3                                                                           Personal Care,Medicine Cabinet,Lubricant/Spermicide,Health,Sexual Wellness,Lubricants
# 4                                                                           Personal Care,Medicine Cabinet,Lubricant/Spermicide,Health,Sexual Wellness,Lubricants
#
#                          manufacturer  \
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# 3                                 K-Y
# 4                                 K-Y
#
#                                          name              reviews_date  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  2012-11-30T06:21:45.000Z
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  2017-07-09T00:00:00.000Z
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  2017-07-09T00:00:00.000Z
# 3            K-Y Love Sensuality Pleasure Gel  2016-01-06T00:00:00.000Z
# 4            K-Y Love Sensuality Pleasure Gel  2016-12-21T00:00:00.000Z
#
#   reviews_didPurchase reviews_doRecommend  reviews_rating  \
# 0                 NaN                 NaN               5
# 1                True                 NaN               5
# 2                True                 NaN               5
# 3               False               False               1
# 4               False               False               1
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                reviews_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 i love this album. it's very good. more to the hip hop side than her current pop sound.. SO HYPE! i listen to this everyday at the gym! i give it 5star rating all the way. her metaphors are just crazy.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Good flavor. This review was collected as part of a promotion.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Good flavor.
# 3  I read through the reviews on here before looking in to buying one of the couples lubricants, and was ultimately disappointed that it didn't even live up to the reviews I had read. For starters, neither my boyfriend nor I could notice any sort of enhanced or 'captivating' sensation. What we did notice, however, was the messy consistency that was reminiscent of a more liquid-y vaseline. It was difficult to clean up, and was not a pleasant, especially since it lacked the 'captivating' sensation we had both been expecting. I'm disappointed that I paid as much as I did for a lube that I won't use again, when I could just use their normal personal lubricant for 1) less money and 2) less mess.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      My husband bought this gel for us. The gel caused irritation and it felt like it was burning my skin. I wouldn't recommend this gel.
#
#   reviews_title reviews_userCity reviews_userProvince reviews_username  \
# 0  Just Awesome      Los Angeles                  NaN           joshua
# 1          Good              NaN                  NaN        dorothy w
# 2          Good              NaN                  NaN        dorothy w
# 3  Disappointed              NaN                  NaN          rebecca
# 4    Irritation              NaN                  NaN        walker557
#
#   user_sentiment
# 0       Positive
# 1       Positive
# 2       Positive
# 3       Negative
# 4       Negative

# %% [markdown]
# <font color=blue>
#
# #### Understand different columns and datatypes in dataframe
#
# </font>

# %%
#print the information of dataframe to check their data types.
df_review.info()
print(df_review.columns.values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    30000 non-null  object
#  1   brand                 30000 non-null  object
#  2   categories            30000 non-null  object
#  3   manufacturer          29859 non-null  object
#  4   name                  30000 non-null  object
#  5   reviews_date          29954 non-null  object
#  6   reviews_didPurchase   15932 non-null  object
#  7   reviews_doRecommend   27430 non-null  object
#  8   reviews_rating        30000 non-null  int64
#  9   reviews_text          30000 non-null  object
#  10  reviews_title         29810 non-null  object
#  11  reviews_userCity      1929 non-null   object
#  12  reviews_userProvince  170 non-null    object
#  13  reviews_username      29937 non-null  object
#  14  user_sentiment        29999 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 3.4+ MB
# ['id' 'brand' 'categories' 'manufacturer' 'name' 'reviews_date'
#  'reviews_didPurchase' 'reviews_doRecommend' 'reviews_rating'
#  'reviews_text' 'reviews_title' 'reviews_userCity' 'reviews_userProvince'
#  'reviews_username' 'user_sentiment']

# %%
#print the shape of the Dataframe
df_review.shape
# Out:
# (30000, 15)

# %%
#describe the data frame
df_review.describe()
# Out:
#        reviews_rating
# count    30000.000000
# mean         4.483133
# std          0.988441
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000

# %% [markdown]
# # <span style ='background:skyblue'> Step 2: Data Cleaning.
#
# ### Step 2.1 Fixing the Rows and Columns.
# </span>
#
# <font color=blue>
#
# #### Checking and fixing columns with NaN values
# </font>

# %%
# Find missing values/ % of null values percentage in the data set
null_values_per_column = (100*round((df_review.isnull().sum())/len(df_review),2)).sort_values(ascending=False)
print("% of null values per column:")
print(null_values_per_column)
# Out:
# % of null values per column:
# reviews_userProvince    99.0
# reviews_userCity        94.0
# reviews_didPurchase     47.0
# reviews_doRecommend      9.0
# reviews_title            1.0
# user_sentiment           0.0
# reviews_username         0.0
# reviews_text             0.0
# reviews_rating           0.0
# reviews_date             0.0
# name                     0.0
# manufacturer             0.0
# categories               0.0
# brand                    0.0
# id                       0.0
# dtype: float64

# %% [markdown]
#
# ####  Here we see reviews_userProvince and reviews_userCity has ,more than 90% missing values and is not useful for our analysis, so removing these two columns. We also dont need reviews_doRecommend column. Lets drop it as well

# %%
df_review = df_review.drop('reviews_userProvince',axis=1)
df_review = df_review.drop('reviews_userCity',axis=1)
df_review = df_review.drop('reviews_doRecommend',axis=1)

# %% [markdown]
# #### We will also drop reviews_didPurchase as it has half of the values as null

# %%
df_review = df_review.drop('reviews_didPurchase',axis=1)

# %% [markdown]
# #### Create a new columns 'reviews' by merging the reviews_text and reviews_title columns

# %%
#create a new columns 'reviews' by merging the reviews_text and reviews_title columns
df_review['reviews'] = df_review['reviews_title']+ " "+df_review['reviews_text']

# %%
#Drop the existing reviews_text  column
df_review.drop(['reviews_text'], axis =1 ,inplace = True)

# %%
df_review.duplicated().sum()
# Out:
# 19

# %%
df_review = df_review.drop_duplicates()

# %%
df_review.duplicated().sum()
# Out:
# 0

# %%
#Create a clean dataframe
df_clean_review = df_review[['name','reviews_username','reviews_rating','user_sentiment','reviews']]

# %%
df_clean_review.head()
# Out:
#                                          name reviews_username  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)           joshua
# 1  Lundberg Organic Cinnamon Toast Rice Cakes        dorothy w
# 2  Lundberg Organic Cinnamon Toast Rice Cakes        dorothy w
# 3            K-Y Love Sensuality Pleasure Gel          rebecca
# 4            K-Y Love Sensuality Pleasure Gel        walker557
#
#    reviews_rating user_sentiment  \
# 0               5       Positive
# 1               5       Positive
# 2               5       Positive
# 3               1       Negative
# 4               1       Negative
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  reviews
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Just Awesome i love this album. it's very good. more to the hip hop side than her current pop sound.. SO HYPE! i listen to this everyday at the gym! i give it 5star rating all the way. her metaphors are just crazy.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Good Good flavor. This review was collected as part of a promotion.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Good Good flavor.
# 3  Disappointed I read through the reviews on here before looking in to buying one of the couples lubricants, and was ultimately disappointed that it didn't even live up to the reviews I had read. For starters, neither my boyfriend nor I could notice any sort of enhanced or 'captivating' sensation. What we did notice, however, was the messy consistency that was reminiscent of a more liquid-y vaseline. It was difficult to clean up, and was not a pleasant, especially since it lacked the 'captivating' sensation we had both been expecting. I'm disappointed that I paid as much as I did for a lube that I won't use again, when I could just use their normal personal lubricant for 1) less money and 2) less mess.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Irritation My husband bought this gel for us. The gel caused irritation and it felt like it was burning my skin. I wouldn't recommend this gel.

# %%
#ccheck the columns, non-null count, datatype of each column
df_clean_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29981 entries, 0 to 29999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              29981 non-null  object
#  1   reviews_username  29918 non-null  object
#  2   reviews_rating    29981 non-null  int64
#  3   user_sentiment    29980 non-null  object
#  4   reviews           29795 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df_clean_review.shape
# Out:
# (29981, 5)

# %%
#describe the data frame
df_clean_review.describe()
# Out:
#        reviews_rating
# count    29981.000000
# mean         4.482906
# std          0.988636
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000

# %%
# Find missing values/ % of null values percentage in the data set
null_values_per_column = (100*round((df_clean_review.isnull().sum())/len(df_review),2)).sort_values(ascending=False)
print("% of null values per column:")
print(null_values_per_column)
# Out:
# % of null values per column:
# reviews             1.0
# user_sentiment      0.0
# reviews_rating      0.0
# reviews_username    0.0
# name                0.0
# dtype: float64

# %%
df_clean_review.dropna(inplace= True)

# %%
#map postivie sentiment as '1' and negative sentiment as '0'
df_clean_review['user_sentiment']=df_clean_review['user_sentiment'].replace({'Positive' :1, "Negative" : 0})

# %%
#Typecasting from float to int datatype
df_clean_review ['user_sentiment'] = df_clean_review['user_sentiment'].astype('int64')

# %%
df_clean_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29732 entries, 0 to 29999
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              29732 non-null  object
#  1   reviews_username  29732 non-null  object
#  2   reviews_rating    29732 non-null  int64
#  3   user_sentiment    29732 non-null  int64
#  4   reviews           29732 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Get the count of each ratings

# %%
df_clean_review.reviews_rating.value_counts()
# Out:
# 5    20639
# 4     5991
# 1     1361
# 3     1332
# 2      409
# Name: reviews_rating, dtype: int64

# %%
df_clean_review.isna().sum()
# Out:
# name                0
# reviews_username    0
# reviews_rating      0
# user_sentiment      0
# reviews             0
# dtype: int64

# %%
#Grapsh for the review_ratings Vs Length of the processed_reviews
import seaborn as sns
text_len = [len(text) for text in df_clean_review['reviews']]

plt.figure(figsize=[12,6])
sns.histplot(data=text_len,bins=20)
plt.title('Distribution of Reviews Length', fontsize = 25)
plt.xlabel('Reviews Text Length', size = 20)
plt.ylabel('Number of Reviews',size=20)
plt.show()

# %% [markdown]
# ## Text Processing
#
#
#
# * Remove Stopwords
# * Make the text lowercase
# * Remove text in square brackets
# * Remove punctuation
# * Remove words containing number
#
#
# Once you have done these cleaning operations you need to perform the following:
# * Lemmatize the texts
# * Use POS tags to get relevant words from the texts.

# %%
#Common functions for cleaning the text data 
import nltk
from nltk.stem import LancasterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
import unicodedata
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize, regexp_tokenize 
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re
import html

# special_characters removal
def remove_special_characters(text, remove_digits=True):
    """Remove the special Characters"""
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words

def remove_punctuation_and_splchars(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_word = remove_special_characters(new_word, True)
            new_words.append(new_word)
    return new_words

stopword_list= stopwords.words('english')

def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopword_list:
            new_words.append(word)
    return new_words

def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
    return stems

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

def normalize(words):
    words = to_lowercase(words)
    words = remove_punctuation_and_splchars(words)
    words = remove_stopwords(words)
    return words

def lemmatize(words):
    lemmas = lemmatize_verbs(words)
    return lemmas
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\geddamsg\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\geddamsg\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\geddamsg\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\geddamsg\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
def normalize_and_lemmaize(input_text):
    input_text = remove_special_characters(input_text)
    words = nltk.word_tokenize(input_text)
    words = normalize(words)
    lemmas = lemmatize(words)
    return ' '.join(lemmas)

# %%
# Add a column for lemmatized review to the dataframe
df_clean_review["final_review"] =  df_clean_review.apply(lambda x: normalize_and_lemmaize(x['reviews']), axis=1)
#final_review = lemmatized review

# %%
df_clean_review.head()
# Out:
#                                          name reviews_username  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)           joshua
# 1  Lundberg Organic Cinnamon Toast Rice Cakes        dorothy w
# 2  Lundberg Organic Cinnamon Toast Rice Cakes        dorothy w
# 3            K-Y Love Sensuality Pleasure Gel          rebecca
# 4            K-Y Love Sensuality Pleasure Gel        walker557
#
#    reviews_rating  user_sentiment  \
# 0               5               1
# 1               5               1
# 2               5               1
# 3               1               0
# 4               1               0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  reviews  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Just Awesome i love this album. it's very good. more to the hip hop side than her current pop sound.. SO HYPE! i listen to this everyday at the gym! i give it 5star rating all the way. her metaphors are just crazy.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Good Good flavor. This review was collected as part of a promotion.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Good Good flavor.
# 3  Disappointed I read through the reviews on here before looking in to buying one of the couples lubricants, and was ultimately disappointed that it didn't even live up to the reviews I had read. For starters, neither my boyfriend nor I could notice any sort of enhanced or 'captivating' sensation. What we did notice, however, was the messy consistency that was reminiscent of a more liquid-y vaseline. It was difficult to clean up, and was not a pleasant, especially since it lacked the 'captivating' sensation we had both been expecting. I'm disappointed that I paid as much as I did for a lube that I won't use again, when I could just use their normal personal lubricant for 1) less money and 2) less mess.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Irritation My husband bought this gel for us. The gel caused irritation and it felt like it was burning my skin. I wouldn't recommend this gel.
#
#                                                                                                                                                                                                                                                                                                                                                                                                              final_review
# 0                                                                                                                                                                                                                                                                                                       awesome love album good hip hop side current pop sound hype listen everyday gym give star rat way metaphors crazy
# 1                                                                                                                                                                                                                                                                                                                                                                          good good flavor review collect part promotion
# 2                                                                                                                                                                                                                                                                                                                                                                                                        good good flavor
# 3  disappoint read review look buy one couple lubricants ultimately disappoint didnt even live review read starters neither boyfriend could notice sort enhance captivate sensation notice however messy consistency reminiscent liquidy vaseline difficult clean pleasant especially since lack captivate sensation expect im disappoint pay much lube wont use could use normal personal lubricant less money less mess
# 4                                                                                                                                                                                                                                                                                                                            irritation husband buy gel us gel cause irritation felt like burn skin wouldnt recommend gel

# %% [markdown]
# ### Class Imbalance Handling Using SMOTE

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE

# %%
# Train and Test Divide
x_train,x_test,y_train,y_test = train_test_split(df_clean_review['final_review'],df_clean_review['user_sentiment'],train_size=0.75,random_state=45,stratify=df_clean_review['user_sentiment'])
y_train.value_counts()
# Out:
# 1    19798
# 0     2501
# Name: user_sentiment, dtype: int64

# %% [markdown]
# ### Feature Extraction - TD-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer
count_vect = CountVectorizer()
x_count = count_vect.fit_transform(x_train)


tfidf_transformer = TfidfTransformer()
x_train_transformed = tfidf_transformer.fit_transform(x_count)
x_train_transformed.shape
# Out:
# (22299, 15349)

# %%
# #creating the pickle for countvectorizer and TFIDF Transformer
import pickle
pickle.dump(count_vect,open("./Pickle/count_vector.pkl","wb"))
pickle.dump(tfidf_transformer,open("./Pickle/tfidf_transformer.pkl","wb"))

# %%
count = Counter(y_train)
print('Before sampling :',count)

sampler = SMOTE()

x_train_sm,y_train_sm = sampler.fit_resample(x_train_transformed,y_train)

count = Counter(y_train_sm)
print('After sampling :',count)
# Out:
# Before sampling : Counter({1: 19798, 0: 2501})
# After sampling : Counter({1: 19798, 0: 19798})

# %% [markdown]
# ### Model Building
# I will try atleast 3 models on the train & test data from these options:
# * Logistic regression
# * Decision Tree
# * Random Forest
# * XGBooost
# * Naive Bayes
#
# **Using the required evaluation metrics judge the tried models and select the ones performing the best**

# %%
# Function for Metrics
performance=[]

def model_metrics(y,y_pred,model_name,metrics):
  Accuracy = accuracy_score(y,y_pred)
  roc = roc_auc_score(y,y_pred)
  confusion = confusion_matrix(y,y_pred)
  precision = precision_score(y,y_pred)
  f1 = f1_score(y,y_pred)
  TP = confusion[1,1]  # true positive
  TN = confusion[0,0]  # true negatives
  FP = confusion[0,1]  # false positives
  FN = confusion[1,0]  # false negatives
  sensitivity= TP / float(TP+FN)
  specificity = TN / float(TN+FP)

  print("*"*50)
  print('Confusion Matrix =')
  print(confusion)
  print("sensitivity of the %s = %f" % (model_name,round(sensitivity,2)))
  print("specificity of the %s = %f" % (model_name,round(specificity,2)))
  print("Accuracy Score of %s = %f" % (model_name,Accuracy))
  print('ROC AUC score of %s = %f' % (model_name,roc))
  print("Report=",)
  print(classification_report(y,y_pred))
  print("*"*50)
  metrics.append(dict({'Model_name':model_name,
                       'Accuracy':Accuracy,
                       'Roc_auc_score':roc,
                       'Precision':precision,
                       'F1_score':f1}))
  return metrics

# %% [markdown]
# ## Logistic Regression

# %%
# 1. Logsitic Regression 
lr = LogisticRegression(solver='liblinear')
lr.fit(x_train_sm,y_train_sm)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred = lr.predict(x_train_sm)
peformance = model_metrics(y_train_sm,y_pred,'Logistic Regression',performance)
# Out:
# **************************************************
# Confusion Matrix =
# [[19043   755]
#  [ 2012 17786]]
# sensitivity of the Logistic Regression = 0.900000
# specificity of the Logistic Regression = 0.960000
# Accuracy Score of Logistic Regression = 0.930119
# ROC AUC score of Logistic Regression = 0.930119
# Report=
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93     19798
#            1       0.96      0.90      0.93     19798
#
#     accuracy                           0.93     39596
#    macro avg       0.93      0.93      0.93     39596
# weighted avg       0.93      0.93      0.93     39596
#
# **************************************************

# %%
# import pickle
# pickle.dump(lr,open("./Pickle/LogisticRegression.pkl","wb"))

# %% [markdown]
# ## RandomForest Classifier

# %%
# 2. RandomForest Classifier
rf = RandomForestClassifier()
rf.fit(x_train_sm,y_train_sm)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf = rf.predict(x_train_sm)
performance = model_metrics(y_train_sm,y_pred_rf,'RandomForestClassifier',performance)
# Out:
# **************************************************
# Confusion Matrix =
# [[19797     1]
#  [    1 19797]]
# sensitivity of the RandomForestClassifier = 1.000000
# specificity of the RandomForestClassifier = 1.000000
# Accuracy Score of RandomForestClassifier = 0.999949
# ROC AUC score of RandomForestClassifier = 0.999949
# Report=
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19798
#            1       1.00      1.00      1.00     19798
#
#     accuracy                           1.00     39596
#    macro avg       1.00      1.00      1.00     39596
# weighted avg       1.00      1.00      1.00     39596
#
# **************************************************

# %% [markdown]
# ## Gradient Boost_AdaBoost Classifier

# %%
xgba = GradientBoostingClassifier()
xgba.fit(x_train_sm,y_train_sm)
y_pred_xgb = xgba.predict(x_train_sm)
peformance = model_metrics(y_train_sm,y_pred_rf,'AdaBoostclassifier',peformance)
# Out:
# **************************************************
# Confusion Matrix =
# [[19797     1]
#  [    1 19797]]
# sensitivity of the AdaBoostclassifier = 1.000000
# specificity of the AdaBoostclassifier = 1.000000
# Accuracy Score of AdaBoostclassifier = 0.999949
# ROC AUC score of AdaBoostclassifier = 0.999949
# Report=
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19798
#            1       1.00      1.00      1.00     19798
#
#     accuracy                           1.00     39596
#    macro avg       1.00      1.00      1.00     39596
# weighted avg       1.00      1.00      1.00     39596
#
# **************************************************

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# %%
#4.XGBoostClassifier
xgb_classifier = xgb.XGBClassifier()
xgb_classifier.fit(x_train_sm,y_train_sm)
y_pred_xgbc = xgb_classifier.predict(x_train_sm)
peformance = model_metrics(y_train_sm,y_pred_xgbc,'XGBClassifier',peformance)
# Out:
# **************************************************
# Confusion Matrix =
# [[18860   938]
#  [  935 18863]]
# sensitivity of the XGBClassifier = 0.950000
# specificity of the XGBClassifier = 0.950000
# Accuracy Score of XGBClassifier = 0.952697
# ROC AUC score of XGBClassifier = 0.952697
# Report=
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     19798
#            1       0.95      0.95      0.95     19798
#
#     accuracy                           0.95     39596
#    macro avg       0.95      0.95      0.95     39596
# weighted avg       0.95      0.95      0.95     39596
#
# **************************************************

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

# %%
# #5.Naive Bayes /ACTUAL CODE/
# #from sklearn.naive_bayes import MultinomialNB, BernoulliNB
# nb_classifier = MultinomialNB()
# nb_classifier.fit(x_train_sm,y_train_sm)
# y_pred_nbc = nb_classifier.predict(x_train_sm)
# peformance = model_metrics(y_train_sm,y_pred_nbc,'NBClassifier_MultinomialNB',peformance)

# %%
#5.Naive Bayes
#from sklearn.naive_bayes import MultinomialNB, BernoulliNB
nb_classifier = MultinomialNB()
nb_classifier_model=nb_classifier.fit(x_train_sm,y_train_sm)
y_pred_nbc = nb_classifier_model.predict(x_train_sm)
peformance = model_metrics(y_train_sm,y_pred_nbc,'NBClassifier_MultinomialNB',peformance)
# Out:
# **************************************************
# Confusion Matrix =
# [[17727  2071]
#  [ 2588 17210]]
# sensitivity of the NBClassifier_MultinomialNB = 0.870000
# specificity of the NBClassifier_MultinomialNB = 0.900000
# Accuracy Score of NBClassifier_MultinomialNB = 0.882337
# ROC AUC score of NBClassifier_MultinomialNB = 0.882337
# Report=
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88     19798
#            1       0.89      0.87      0.88     19798
#
#     accuracy                           0.88     39596
#    macro avg       0.88      0.88      0.88     39596
# weighted avg       0.88      0.88      0.88     39596
#
# **************************************************

# %%
metrics_df = pd.DataFrame(performance)
metrics_df
# Out:
#                    Model_name  Accuracy  Roc_auc_score  Precision  F1_score
# 0         Logistic Regression  0.930119       0.930119   0.959279  0.927828
# 1      RandomForestClassifier  0.999949       0.999949   0.999949  0.999949
# 2          AdaBoostclassifier  0.999949       0.999949   0.999949  0.999949
# 3               XGBClassifier  0.952697       0.952697   0.952629  0.952701
# 4  NBClassifier_MultinomialNB  0.882337       0.882337   0.892589  0.880780

# %% [markdown]
# ## Hyperparameter Tuning of models
# Perform Tuning of atleast 2 models and then choose best model

# %% [markdown]
# ### Logistic Regression_HyperParameter Tuning

# %%
#Evaluation between lr , rf and boost 
test_performance=[]
test_word_vect = count_vect.transform(x_test)
test_tfidf_vect = tfidf_transformer.transform(test_word_vect)

y_test_pred_lr = lr.predict(test_tfidf_vect)
test_peformance = model_metrics(y_test,y_test_pred_lr,'Logistic Regression',test_performance)
# Out:
# **************************************************
# Confusion Matrix =
# [[ 635  199]
#  [ 789 5810]]
# sensitivity of the Logistic Regression = 0.880000
# specificity of the Logistic Regression = 0.760000
# Accuracy Score of Logistic Regression = 0.867079
# ROC AUC score of Logistic Regression = 0.820914
# Report=
#               precision    recall  f1-score   support
#
#            0       0.45      0.76      0.56       834
#            1       0.97      0.88      0.92      6599
#
#     accuracy                           0.87      7433
#    macro avg       0.71      0.82      0.74      7433
# weighted avg       0.91      0.87      0.88      7433
#
# **************************************************

# %%
lr_tuned = LogisticRegression()

# %%
# Hyperparameter tuning for best result
param_nb = {'class_weight':['balanced'],'penalty' : ['l1','l2'],'C':[1,5,10], }

grid_nb = GridSearchCV(estimator=lr_tuned, 
                       param_grid=param_nb,
                       verbose=1,
                       scoring='accuracy',
                       n_jobs=-1,
                       cv=4)
grid_nb.fit(x_train_sm, y_train_sm)
#print(grid_nb.best_params_)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits
# GridSearchCV(cv=4, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [1, 5, 10], 'class_weight': ['balanced'],
#                          'penalty': ['l1', 'l2']},
#              scoring='accuracy', verbose=1)

# %%
# Creating model with best hyperparameter
lr_tuned_model=grid_nb.fit(x_train_sm,y_train_sm)
y_pred_lr_tuned = lr_tuned_model.predict(test_tfidf_vect)
# Out:
# Fitting 4 folds for each of 6 candidates, totalling 24 fits

# %%
#Evaluation between lr , rf and boost 
test_performance=[]
test_word_vect = count_vect.transform(x_test)
test_tfidf_vect = tfidf_transformer.transform(test_word_vect)

y_test_pred_lr = lr_tuned_model.predict(test_tfidf_vect)
test_peformance = model_metrics(y_test,y_pred_lr_tuned,'LogisticRegression_Classifier',test_performance)
# Out:
# **************************************************
# Confusion Matrix =
# [[ 579  255]
#  [ 645 5954]]
# sensitivity of the LogisticRegression_Classifier = 0.900000
# specificity of the LogisticRegression_Classifier = 0.690000
# Accuracy Score of LogisticRegression_Classifier = 0.878918
# ROC AUC score of LogisticRegression_Classifier = 0.798251
# Report=
#               precision    recall  f1-score   support
#
#            0       0.47      0.69      0.56       834
#            1       0.96      0.90      0.93      6599
#
#     accuracy                           0.88      7433
#    macro avg       0.72      0.80      0.75      7433
# weighted avg       0.90      0.88      0.89      7433
#
# **************************************************

# %% [markdown]
# ###  XGBoost _HyperParameter Tuning

# %%
n_estimators = [200,400,600]
params_1 = {'n_estimators':n_estimators}

# %%
grid_cv_boost = GridSearchCV(estimator=xgba,
                       param_grid=params_1,
                       n_jobs = -1,
                       scoring = 'roc_auc',
                       verbose = 1)

# %%
grid_cv_boost.fit(x_train_sm,y_train_sm)
print('Best score for GradientBoosting=',grid_cv_boost.best_score_)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Best score for GradientBoosting= 0.9713239691991109

# %%
xgb_final=grid_cv_boost.best_estimator_
xgb_final
# Out:
# GradientBoostingClassifier(n_estimators=600)

# %%
y_pred_xgbgcv = xgb_final.predict(x_train_sm)
peformance = model_metrics(y_train_sm,y_pred_xgbgcv,'GradientBoostClassifier with n = 600',peformance)
# Out:
# **************************************************
# Confusion Matrix =
# [[18991   807]
#  [ 1642 18156]]
# sensitivity of the GradientBoostClassifier with n = 600 = 0.920000
# specificity of the GradientBoostClassifier with n = 600 = 0.960000
# Accuracy Score of GradientBoostClassifier with n = 600 = 0.938150
# ROC AUC score of GradientBoostClassifier with n = 600 = 0.938150
# Report=
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94     19798
#            1       0.96      0.92      0.94     19798
#
#     accuracy                           0.94     39596
#    macro avg       0.94      0.94      0.94     39596
# weighted avg       0.94      0.94      0.94     39596
#
# **************************************************

# %%
metrics_df = pd.DataFrame(performance)
metrics_df
# Out:
#                              Model_name  Accuracy  Roc_auc_score  Precision  \
# 0                   Logistic Regression  0.930119       0.930119   0.959279
# 1                RandomForestClassifier  0.999949       0.999949   0.999949
# 2                    AdaBoostclassifier  0.999949       0.999949   0.999949
# 3                         XGBClassifier  0.952697       0.952697   0.952629
# 4            NBClassifier_MultinomialNB  0.882337       0.882337   0.892589
# 5  GradientBoostClassifier with n = 600  0.938150       0.938150   0.957443
#
#    F1_score
# 0  0.927828
# 1  0.999949
# 2  0.999949
# 3  0.952701
# 4  0.880780
# 5  0.936818

# %%
# After doing multiple tuning we get the below model and will be used in the sentiment based analysis
final_model = RandomForestClassifier(max_depth=15, min_samples_leaf=5, n_estimators=400)

# %%
final_model.fit(x_train_sm,y_train_sm)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_leaf=5, n_estimators=400)

# %% [markdown]
# ## Evaluation between LR,RF,NB, XGboost

# %%
#Evaluation between lr , rf and boost 
test_performance=[]
test_word_vect = count_vect.transform(x_test)
test_tfidf_vect = tfidf_transformer.transform(test_word_vect)

y_test_pred_lr = lr.predict(test_tfidf_vect)
test_peformance = model_metrics(y_test,y_test_pred_lr,'Logistic Regression',test_performance)

y_test_pred_lr = lr_tuned_model.predict(test_tfidf_vect)
test_peformance = model_metrics(y_test,y_pred_lr_tuned,'Tuned LogisticRegression',test_performance)

y_test_pred_xgbc = xgb_classifier.predict(test_tfidf_vect)
test_peformance = model_metrics(y_test,y_test_pred_xgbc,'XGBoost Classifier',test_performance)

y_test_pred_xgb = final_model.predict(test_tfidf_vect)
test_peformance = model_metrics(y_test,y_test_pred_xgb,'Tuned XGBoostClassifier',test_performance)

y_test_pred_nbc = final_model.predict(test_tfidf_vect)
peformance = model_metrics(y_train_sm,y_pred_nbc,'NBClassifier_MultinomialNB',test_peformance)

# %%
test_metrics_df = pd.DataFrame(test_performance)
test_metrics_df
# Out:
#                                   Model_name  Accuracy  Roc_auc_score  \
# 0                        Logistic Regression  0.867079       0.820914
# 1                   Tuned LogisticRegression  0.878918       0.798251
# 2                         XGBoost Classifier  0.894524       0.760427
# 3                 NBClassifier_MultinomialNB  0.882337       0.882337
# 4                    Tuned XGBoostClassifier  0.847975       0.695453
# 5                              XGBClassifier  0.952697       0.952697
# 6  TunedGradientBoostClassifier with n = 600  0.938150       0.938150
#
#    Precision  F1_score
# 0   0.966883  0.921637
# 1   0.958931  0.929731
# 2   0.947101  0.940162
# 3   0.892589  0.880780
# 4   0.933703  0.912430
# 5   0.952629  0.952701
# 6   0.957443  0.936818

# %% [markdown]
# ### Evaluation with test data after comparing
# - After Hyperparameter Tuning Considering roc_auc_score ,performance, Logistic Regression is having more score and have good accuracy. This will be our final model

# %%
# Load the final model - Naive Bayes nto pickle file
import pickle
pickle.dump(lr_tuned_model,open("./Pickle/model.pkl","wb"))

# %% [markdown]
# # 5. Recommedation system
# - User and User recommedation system
# - Item and Item recommedation system

# %% [markdown]
# ## User and User recommedation

# %% [markdown]
# ### Load the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('sample30.csv')

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,train_size=0.70,random_state=45)
print('train shape = ',train.shape)
print('test shape = ',test.shape)
# Out:
# train shape =  (21000, 15)
# test shape =  (9000, 15)

# %% [markdown]
# ### Dividing the dataset into train and test

# %%
#using train dataset and create correlation matrix 
train_pivot = pd.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating',data=train).fillna(1)

# %%
#Creating the train and test dataset for predicting and evaluating the correlation
#fill 1 in place of Nan for prediction 
train_pivot1 = pd.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating',data=train).fillna(1)

# %%
train_pivot1.loc['joshua']
# Out:
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. Fire File Chest           1.0
# 100:Complete First Season (blu-Ray)                                     1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planner 8 1/2 X 11 Black       1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                                  1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"                           1.0
#                                                                        ...
# WeatherTech 40647 14-15 Outlander Cargo Liners Behind 2nd Row, Black    1.0
# Weleda Everon Lip Balm                                                  1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 Liter)                   1.0
# Yes To Carrots Nourishing Body Wash                                     1.0
# Yes To Grapefruit Rejuvenating Body Wash                                1.0
# Name: joshua, Length: 254, dtype: float64

# %%
# here we are going use the adjusted cosine similarity 
import numpy as np

def cosine_similarity(df):
    # using the adjusted cosine similarity 
    mean_df = np.nanmean(df,axis=1)
    substracted_df = (df.T - mean_df).T # Normalized dataset
    # using the pairwise_distance for cosine similarity 
    user_correlation = 1- pairwise_distances (substracted_df.fillna(0),metric='cosine')
    user_correlation[np.isnan(user_correlation)] = 0
    return user_correlation,substracted_df

# %%
from sklearn.metrics import pairwise_distances
user_corr_matrix,normalized_df = cosine_similarity(train_pivot1)

# %%
user_corr_matrix
# Out:
# array([[ 1.        , -0.00395257, -0.00395257, ..., -0.00395257,
#         -0.00395257,  1.        ],
#        [-0.00395257,  1.        ,  1.        , ..., -0.00395257,
#         -0.00395257, -0.00395257],
#        [-0.00395257,  1.        ,  1.        , ..., -0.00395257,
#         -0.00395257, -0.00395257],
#        ...,
#        [-0.00395257, -0.00395257, -0.00395257, ...,  1.        ,
#          1.        , -0.00395257],
#        [-0.00395257, -0.00395257, -0.00395257, ...,  1.        ,
#          1.        , -0.00395257],
#        [ 1.        , -0.00395257, -0.00395257, ..., -0.00395257,
#         -0.00395257,  1.        ]])

# %%
user_corr_matrix.shape
# Out:
# (18205, 18205)

# %%
user_corr_matrix[user_corr_matrix < 0] = 0
user_corr_matrix.shape
# Out:
# (18205, 18205)

# %%
df[df['reviews_username'] == 'kimmi']
# Out:
#                          id                 brand  \
# 2700   AVpe59io1cnluZ0-ZgDU  Universal Home Video
# 16097  AVpf63aJLJeJML43F__Q           Burt's Bees
#
#                                               categories manufacturer  \
# 2700   Movies, Music & Books,Movies,Comedy,Movies & T...    Universal
# 16097  Personal Care,Makeup,Lipstick, Lip Gloss, & Li...  Burt's Bees
#
#                                                     name  \
# 2700   My Big Fat Greek Wedding 2 (blu-Ray + Dvd + Di...
# 16097                    Burt's Bees Lip Shimmer, Raisin
#
#                    reviews_date reviews_didPurchase reviews_doRecommend  \
# 2700   2016-08-05T00:00:00.000Z                 NaN                True
# 16097  2009-08-28T00:00:00.000Z               False                True
#
#        reviews_rating                                       reviews_text  \
# 2700                4  I think the first movie was better but still g...
# 16097               5  This is perfect for everyday. Keeps my lips so...
#
#       reviews_title reviews_userCity reviews_userProvince reviews_username  \
# 2700    Funny movie              NaN                  NaN            kimmi
# 16097   Really Nice              NaN                  NaN            kimmi
#
#       user_sentiment
# 2700        Positive
# 16097       Positive

# %%
user_pred_ratings = np.dot(user_corr_matrix,train_pivot1.fillna(0))
user_pred_ratings
# Out:
# array([[ 437.75576386,  438.26995035,  437.75576386, ...,  443.40142748,
#          440.05601875,  437.75576386],
#        [2120.11694472, 2138.77377911, 2120.11694472, ..., 2132.78849166,
#         2120.11694472, 2121.98528539],
#        [2120.11694472, 2138.77377911, 2120.11694472, ..., 2132.78849166,
#         2120.11694472, 2121.98528539],
#        ...,
#        [5461.34652523, 5465.56431548, 5461.34652523, ..., 5467.89333212,
#         5464.16935704, 5461.34652523],
#        [5461.34652523, 5465.56431548, 5461.34652523, ..., 5467.89333212,
#         5464.16935704, 5461.34652523],
#        [ 437.75576386,  438.26995035,  437.75576386, ...,  443.40142748,
#          440.05601875,  437.75576386]])

# %%
user_pred_ratings.shape
# Out:
# (18205, 254)

# %%
user_final_rating = np.multiply(user_pred_ratings,train_pivot)

# %%
user_final_rating.head(5)
# Out:
# name              0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. Fire File Chest  \
# reviews_username
# 00sab00                                                  437.755764
# 02dakota                                                2120.116945
# 02deuce                                                 2120.116945
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              100:Complete First Season (blu-Ray)  \
# reviews_username
# 00sab00                                    438.269950
# 02dakota                                  2138.773779
# 02deuce                                   2138.773779
# 0325home                                  5465.564315
# 06stidriver                               5465.564315
#
# name              2017-2018 Brownline174 Duraflex 14-Month Planner 8 1/2 X 11 Black  \
# reviews_username
# 00sab00                                                  437.755764
# 02dakota                                                2120.116945
# 02deuce                                                 2120.116945
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              2x Ultra Era with Oxi Booster, 50fl oz  \
# reviews_username
# 00sab00                                       437.755764
# 02dakota                                     2120.116945
# 02deuce                                      2120.116945
# 0325home                                     5461.346525
# 06stidriver                                  5461.346525
#
# name              42 Dual Drop Leaf Table with 2 Madrid Chairs"  \
# reviews_username
# 00sab00                                              440.056019
# 02dakota                                            2120.116945
# 02deuce                                             2120.116945
# 0325home                                            5461.346525
# 06stidriver                                         5461.346525
#
# name              4C Grated Parmesan Cheese 100% Natural 8oz Shaker  \
# reviews_username
# 00sab00                                                  437.755764
# 02dakota                                                2120.116945
# 02deuce                                                 2120.116945
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              5302050 15/16 FCT/HOSE ADAPTOR  \
# reviews_username
# 00sab00                               437.755764
# 02dakota                             2120.116945
# 02deuce                              2120.116945
# 0325home                             5461.346525
# 06stidriver                          5461.346525
#
# name              Africa's Best No-Lye Dual Conditioning Relaxer System Super  \
# reviews_username
# 00sab00                                                  437.755764
# 02dakota                                                2120.116945
# 02deuce                                                 2120.116945
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              Alberto VO5 Salon Series Smooth Plus Sleek Shampoo  \
# reviews_username
# 00sab00                                                  437.755764
# 02dakota                                                2120.116945
# 02deuce                                                 2120.116945
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              Alex Cross (dvdvideo)  ...  Vicks Vaporub, Regular, 3.53oz  \
# reviews_username                         ...
# 00sab00                      441.303557  ...                      437.755764
# 02dakota                    2133.045416  ...                     2120.116945
# 02deuce                     2133.045416  ...                     2120.116945
# 0325home                    5465.138556  ...                     5469.987314
# 06stidriver                 5465.138556  ...                     5469.987314
#
# name              Voortman Sugar Free Fudge Chocolate Chip Cookies  \
# reviews_username
# 00sab00                                                 437.755764
# 02dakota                                               2120.116945
# 02deuce                                                2120.116945
# 0325home                                               5461.346525
# 06stidriver                                            5461.346525
#
# name              Wagan Smartac 80watt Inverter With Usb  \
# reviews_username
# 00sab00                                       437.755764
# 02dakota                                     2121.985285
# 02deuce                                      2121.985285
# 0325home                                     5461.346525
# 06stidriver                                  5461.346525
#
# name              Walkers Stem Ginger Shortbread  \
# reviews_username
# 00sab00                               437.755764
# 02dakota                             2120.116945
# 02deuce                              2120.116945
# 0325home                             5461.346525
# 06stidriver                          5461.346525
#
# name              Way Basics 3-Shelf Eco Narrow Bookcase Storage Shelf, Espresso - Formaldehyde Free - Lifetime Guarantee  \
# reviews_username
# 00sab00                                                  438.873393
# 02dakota                                                2122.191680
# 02deuce                                                 2122.191680
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              WeatherTech 40647 14-15 Outlander Cargo Liners Behind 2nd Row, Black  \
# reviews_username
# 00sab00                                                  437.755764
# 02dakota                                                2120.116945
# 02deuce                                                 2120.116945
# 0325home                                                5461.346525
# 06stidriver                                             5461.346525
#
# name              Weleda Everon Lip Balm  \
# reviews_username
# 00sab00                       437.755764
# 02dakota                     2120.116945
# 02deuce                      2120.116945
# 0325home                     5461.346525
# 06stidriver                  5461.346525
#
# name              Windex Original Glass Cleaner Refill 67.6oz (2 Liter)  \
# reviews_username
# 00sab00                                                  443.401427
# 02dakota                                                2132.788492
# 02deuce                                                 2132.788492
# 0325home                                                5467.893332
# 06stidriver                                             5467.893332
#
# name              Yes To Carrots Nourishing Body Wash  \
# reviews_username
# 00sab00                                    440.056019
# 02dakota                                  2120.116945
# 02deuce                                   2120.116945
# 0325home                                  5464.169357
# 06stidriver                               5464.169357
#
# name              Yes To Grapefruit Rejuvenating Body Wash
# reviews_username
# 00sab00                                         437.755764
# 02dakota                                       2121.985285
# 02deuce                                        2121.985285
# 0325home                                       5461.346525
# 06stidriver                                    5461.346525
#
# [5 rows x 254 columns]

# %% [markdown]
# ### Loading User-User Recommendation System in Pickle file user_final_rating.pkl

# %%
# Creating a pickle file for user-user recommendation system
import pickle 
pickle.dump(user_final_rating,open('./Pickle/user_final_rating.pkl','wb'))

# %% [markdown]
# ### Top20 Product Recommendations

# %%
d = user_final_rating
d.loc['joshua'].sort_values(ascending=False)[:20]
# Out:
# name
# Red (special Edition) (dvdvideo)                                                          3448.574777
# Cheetos Crunchy Flamin' Hot Cheese Flavored Snacks                                        1515.983128
# Smead174 Recycled Letter Size Manila File Backs W/prong Fasteners, 2 Capacity, 100/box    1163.172297
# Pink Friday: Roman Reloaded Re-Up (w/dvd)                                                 1163.172297
# Dark Shadows (includes Digital Copy) (ultraviolet) (dvdvideo)                             1055.651201
# Godzilla 3d Includes Digital Copy Ultraviolet 3d/2d Blu-Ray/dvd                            250.881688
# Mike Dave Need Wedding Dates (dvd + Digital)                                               238.989341
# The Resident Evil Collection 5 Discs (blu-Ray)                                             237.147662
# Planes: Fire Rescue (2 Discs) (includes Digital Copy) (blu-Ray/dvd)                        236.272889
# My Big Fat Greek Wedding 2 (blu-Ray + Dvd + Digital)                                       236.162655
# Tostitos Bite Size Tortilla Chips                                                          232.084488
# Pendaflex174 Divide It Up File Folder, Multi Section, Letter, Assorted, 12/pack            231.890532
# Clorox Disinfecting Wipes Value Pack Scented 150 Ct Total                                  231.446922
# Jason Aldean - They Don't Know                                                             231.273273
# Chester's Cheese Flavored Puffcorn Snacks                                                  231.149741
# Windex Original Glass Cleaner Refill 67.6oz (2 Liter)                                      230.945551
# Coty Airspun Face Powder, Translucent Extra Coverage                                       230.920029
# Alex Cross (dvdvideo)                                                                      230.510886
# Stargate (ws) (ultimate Edition) (director's Cut) (dvdvideo)                               230.281108
# Hormel Chili, No Beans                                                                     230.231373
# Name: joshua, dtype: float64

# %% [markdown]
# ### Evaluation for user-user recommendation system

# %%
## Evaluation
common = test[test.reviews_username.isin(train.reviews_username)]
common.shape
# Out:
# (2006, 15)

# %%
corr_df = pd.DataFrame(user_corr_matrix)

# %%
#corr_df.head

# %%
corr_df['user_name'] = normalized_df.index
corr_df.set_index('user_name',inplace=True)

# %%
#corr_df

# %%
list_name = common.reviews_username.tolist()

# %%
corr_df.columns = normalized_df.index.tolist()
corr_df.columns
# Out:
# Index(['00sab00', '02dakota', '02deuce', '0325home', '06stidriver', '1.11E+24',
#        '1085', '10ten', '11111111aaaaaaaaaaaaaaaaa', '11677j',
#        ...
#        'zowie', 'zozo0o', 'zsazsa', 'zt313', 'zubb', 'zuttle', 'zwithanx',
#        'zxcsdfd', 'zyiah4', 'zzdiane'],
#       dtype='object', length=18205)

# %%
corr_df1 = corr_df[corr_df.index.isin(list_name)]
corr_df1.shape
# Out:
# (1687, 18205)

# %%
corr_df2 = corr_df1.T[corr_df1.T.index.isin(list_name)]
corr_df3 = corr_df2.T
#corr_df3.head()

# %%
common_user_tb = pd.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating',data=common)

# %%
#common_user_tb

# %%
corr_df3[corr_df3<0] = 0
common_user_rating =  np.dot(corr_df3,common_user_tb.fillna(0))
#common_user_rating

# %%
dummy_test = common.copy()
dummy_test['reviews_rating'] =dummy_test['reviews_rating'].apply(lambda x: 1 if x>=1 else 0)
dummy_test = pd.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating',data=dummy_test).fillna(0)
#dummy_test

# %%
common_user_pred_ratings =  np.multiply(common_user_rating,dummy_test)

# %%
common_user_pred_ratings
# Out:
# name              100:Complete First Season (blu-Ray)  Alex Cross (dvdvideo)  \
# reviews_username
# 1234                                              0.0                    0.0
# 123charlie                                        0.0                    0.0
# 143st                                             0.0                    0.0
# 1943                                              0.0                    0.0
# 4cloroxl                                          0.0                    0.0
# ...                                               ...                    ...
# yummy                                             0.0                    0.0
# yvonne                                            0.0                    0.0
# zburt5                                            0.0                    0.0
# zebras                                            0.0                    0.0
# zippy                                             0.0                    0.0
#
# name              Aussie Aussome Volume Shampoo, 13.5 Oz  \
# reviews_username
# 1234                                                 0.0
# 123charlie                                           0.0
# 143st                                                0.0
# 1943                                                 0.0
# 4cloroxl                                             0.0
# ...                                                  ...
# yummy                                                0.0
# yvonne                                               0.0
# zburt5                                               0.0
# zebras                                               0.0
# zippy                                                0.0
#
# name              Australian Gold Exotic Blend Lotion, SPF 4  \
# reviews_username
# 1234                                                     0.0
# 123charlie                                               0.0
# 143st                                                    0.0
# 1943                                                     0.0
# 4cloroxl                                                 0.0
# ...                                                      ...
# yummy                                                    0.0
# yvonne                                                   0.0
# zburt5                                                   0.0
# zebras                                                   0.0
# zippy                                                    0.0
#
# name              Aveeno Baby Continuous Protection Lotion Sunscreen with Broad Spectrum SPF 55, 4oz  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              Avery174 Ready Index Contemporary Table Of Contents Divider, 1-8, Multi, Letter  \
# reviews_username
# 1234                                                       0.000000
# 123charlie                                                 0.000000
# 143st                                                      0.000000
# 1943                                                      68.109936
# 4cloroxl                                                   0.000000
# ...                                                             ...
# yummy                                                      0.000000
# yvonne                                                     0.000000
# zburt5                                                     0.000000
# zebras                                                     0.000000
# zippy                                                      0.000000
#
# name              Axe Dry Anti-Perspirant Deodorant Invisible Solid Phoenix  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              BRIDGESTONE 130/70ZR18M/C(63W)FRONT EXEDRA G851, CRUISER RADL  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              Banana Boat Sunless Summer Color Self Tanning Lotion, Light To Medium  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              Barielle Nail Rebuilding Protein  ...  \
# reviews_username                                    ...
# 1234                                           0.0  ...
# 123charlie                                     0.0  ...
# 143st                                          0.0  ...
# 1943                                           0.0  ...
# 4cloroxl                                       0.0  ...
# ...                                            ...  ...
# yummy                                          0.0  ...
# yvonne                                         0.0  ...
# zburt5                                         0.0  ...
# zebras                                         0.0  ...
# zippy                                          0.0  ...
#
# name              Vaseline Intensive Care Healthy Hands Stronger Nails  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              Vaseline Intensive Care Lip Therapy Cocoa Butter  \
# reviews_username
# 1234                                                           0.0
# 123charlie                                                     0.0
# 143st                                                          0.0
# 1943                                                           0.0
# 4cloroxl                                                       0.0
# ...                                                            ...
# yummy                                                          0.0
# yvonne                                                         0.0
# zburt5                                                         0.0
# zebras                                                         0.0
# zippy                                                          0.0
#
# name              Vicks Vaporub, Regular, 3.53oz  \
# reviews_username
# 1234                                         0.0
# 123charlie                                   0.0
# 143st                                        0.0
# 1943                                         0.0
# 4cloroxl                                     0.0
# ...                                          ...
# yummy                                        0.0
# yvonne                                       0.0
# zburt5                                       0.0
# zebras                                       0.0
# zippy                                        0.0
#
# name              Voortman Sugar Free Fudge Chocolate Chip Cookies  \
# reviews_username
# 1234                                                           0.0
# 123charlie                                                     0.0
# 143st                                                          0.0
# 1943                                                           0.0
# 4cloroxl                                                       0.0
# ...                                                            ...
# yummy                                                          0.0
# yvonne                                                         0.0
# zburt5                                                         0.0
# zebras                                                         0.0
# zippy                                                          0.0
#
# name              Wagan Smartac 80watt Inverter With Usb  \
# reviews_username
# 1234                                                 0.0
# 123charlie                                           0.0
# 143st                                                0.0
# 1943                                                 0.0
# 4cloroxl                                             0.0
# ...                                                  ...
# yummy                                                0.0
# yvonne                                               0.0
# zburt5                                               0.0
# zebras                                               0.0
# zippy                                                0.0
#
# name              Way Basics 3-Shelf Eco Narrow Bookcase Storage Shelf, Espresso - Formaldehyde Free - Lifetime Guarantee  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              WeatherTech 40647 14-15 Outlander Cargo Liners Behind 2nd Row, Black  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              Windex Original Glass Cleaner Refill 67.6oz (2 Liter)  \
# reviews_username
# 1234                                                            0.0
# 123charlie                                                      0.0
# 143st                                                           0.0
# 1943                                                            0.0
# 4cloroxl                                                        0.0
# ...                                                             ...
# yummy                                                           0.0
# yvonne                                                          0.0
# zburt5                                                          0.0
# zebras                                                          0.0
# zippy                                                           0.0
#
# name              Yes To Carrots Nourishing Body Wash  \
# reviews_username
# 1234                                              0.0
# 123charlie                                        0.0
# 143st                                             0.0
# 1943                                              0.0
# 4cloroxl                                          0.0
# ...                                               ...
# yummy                                             0.0
# yvonne                                            0.0
# zburt5                                            0.0
# zebras                                            0.0
# zippy                                             0.0
#
# name              Yes To Grapefruit Rejuvenating Body Wash
# reviews_username
# 1234                                                   0.0
# 123charlie                                             0.0
# 143st                                                  0.0
# 1943                                                   0.0
# 4cloroxl                                               0.0
# ...                                                    ...
# yummy                                                  0.0
# yvonne                                                 0.0
# zburt5                                                 0.0
# zebras                                                 0.0
# zippy                                                  0.0
#
# [1687 rows x 120 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
from numpy import *

X  = common_user_pred_ratings.copy() 
X = X[X>0]

scaler = MinMaxScaler(feature_range=(1, 5))
print(scaler.fit(X))
y = (scaler.transform(X))

print(y)
y.shape
# Out:
# MinMaxScaler(feature_range=(1, 5))
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# C:\Users\geddamsg\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:461: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\geddamsg\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:462: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)
# (1687, 120)

# %%
# Finding total non-NaN value
total_non_nan = np.count_nonzero(~np.isnan(y))

# %%
total_non_nan
# Out:
# 8730

# %%
common_pivot = pd.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating',data=common)

# %%
common_pivot
# Out:
# name              100:Complete First Season (blu-Ray)  Alex Cross (dvdvideo)  \
# reviews_username
# 1234                                              NaN                    NaN
# 123charlie                                        NaN                    NaN
# 143st                                             NaN                    NaN
# 1943                                              NaN                    NaN
# 4cloroxl                                          NaN                    NaN
# ...                                               ...                    ...
# yummy                                             NaN                    NaN
# yvonne                                            NaN                    NaN
# zburt5                                            NaN                    NaN
# zebras                                            NaN                    NaN
# zippy                                             NaN                    NaN
#
# name              Aussie Aussome Volume Shampoo, 13.5 Oz  \
# reviews_username
# 1234                                                 NaN
# 123charlie                                           NaN
# 143st                                                NaN
# 1943                                                 NaN
# 4cloroxl                                             NaN
# ...                                                  ...
# yummy                                                NaN
# yvonne                                               NaN
# zburt5                                               NaN
# zebras                                               NaN
# zippy                                                NaN
#
# name              Australian Gold Exotic Blend Lotion, SPF 4  \
# reviews_username
# 1234                                                     NaN
# 123charlie                                               NaN
# 143st                                                    NaN
# 1943                                                     NaN
# 4cloroxl                                                 NaN
# ...                                                      ...
# yummy                                                    NaN
# yvonne                                                   NaN
# zburt5                                                   NaN
# zebras                                                   NaN
# zippy                                                    NaN
#
# name              Aveeno Baby Continuous Protection Lotion Sunscreen with Broad Spectrum SPF 55, 4oz  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Avery174 Ready Index Contemporary Table Of Contents Divider, 1-8, Multi, Letter  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            5.0
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Axe Dry Anti-Perspirant Deodorant Invisible Solid Phoenix  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              BRIDGESTONE 130/70ZR18M/C(63W)FRONT EXEDRA G851, CRUISER RADL  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Banana Boat Sunless Summer Color Self Tanning Lotion, Light To Medium  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Barielle Nail Rebuilding Protein  ...  \
# reviews_username                                    ...
# 1234                                           NaN  ...
# 123charlie                                     NaN  ...
# 143st                                          NaN  ...
# 1943                                           NaN  ...
# 4cloroxl                                       NaN  ...
# ...                                            ...  ...
# yummy                                          NaN  ...
# yvonne                                         NaN  ...
# zburt5                                         NaN  ...
# zebras                                         NaN  ...
# zippy                                          NaN  ...
#
# name              Vaseline Intensive Care Healthy Hands Stronger Nails  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Vaseline Intensive Care Lip Therapy Cocoa Butter  \
# reviews_username
# 1234                                                           NaN
# 123charlie                                                     NaN
# 143st                                                          NaN
# 1943                                                           NaN
# 4cloroxl                                                       NaN
# ...                                                            ...
# yummy                                                          NaN
# yvonne                                                         NaN
# zburt5                                                         NaN
# zebras                                                         NaN
# zippy                                                          NaN
#
# name              Vicks Vaporub, Regular, 3.53oz  \
# reviews_username
# 1234                                         NaN
# 123charlie                                   NaN
# 143st                                        NaN
# 1943                                         NaN
# 4cloroxl                                     NaN
# ...                                          ...
# yummy                                        NaN
# yvonne                                       NaN
# zburt5                                       NaN
# zebras                                       NaN
# zippy                                        NaN
#
# name              Voortman Sugar Free Fudge Chocolate Chip Cookies  \
# reviews_username
# 1234                                                           NaN
# 123charlie                                                     NaN
# 143st                                                          NaN
# 1943                                                           NaN
# 4cloroxl                                                       NaN
# ...                                                            ...
# yummy                                                          NaN
# yvonne                                                         NaN
# zburt5                                                         NaN
# zebras                                                         NaN
# zippy                                                          NaN
#
# name              Wagan Smartac 80watt Inverter With Usb  \
# reviews_username
# 1234                                                 NaN
# 123charlie                                           NaN
# 143st                                                NaN
# 1943                                                 NaN
# 4cloroxl                                             NaN
# ...                                                  ...
# yummy                                                NaN
# yvonne                                               NaN
# zburt5                                               NaN
# zebras                                               NaN
# zippy                                                NaN
#
# name              Way Basics 3-Shelf Eco Narrow Bookcase Storage Shelf, Espresso - Formaldehyde Free - Lifetime Guarantee  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              WeatherTech 40647 14-15 Outlander Cargo Liners Behind 2nd Row, Black  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Windex Original Glass Cleaner Refill 67.6oz (2 Liter)  \
# reviews_username
# 1234                                                            NaN
# 123charlie                                                      NaN
# 143st                                                           NaN
# 1943                                                            NaN
# 4cloroxl                                                        NaN
# ...                                                             ...
# yummy                                                           NaN
# yvonne                                                          NaN
# zburt5                                                          NaN
# zebras                                                          NaN
# zippy                                                           NaN
#
# name              Yes To Carrots Nourishing Body Wash  \
# reviews_username
# 1234                                              NaN
# 123charlie                                        NaN
# 143st                                             NaN
# 1943                                              NaN
# 4cloroxl                                          NaN
# ...                                               ...
# yummy                                             NaN
# yvonne                                            NaN
# zburt5                                            NaN
# zebras                                            NaN
# zippy                                             NaN
#
# name              Yes To Grapefruit Rejuvenating Body Wash
# reviews_username
# 1234                                                   NaN
# 123charlie                                             NaN
# 143st                                                  NaN
# 1943                                                   NaN
# 4cloroxl                                               NaN
# ...                                                    ...
# yummy                                                  NaN
# yvonne                                                 NaN
# zburt5                                                 NaN
# zebras                                                 NaN
# zippy                                                  NaN
#
# [1687 rows x 120 columns]

# %% [markdown]
# ### Calculate RMSE

# %%
rmse = (sum(sum((common_pivot -  y )**2))/total_non_nan)**0.5
print(rmse)
# Out:
# 1.875589018465046

# %% [markdown]
# ## Item and Item recommendation system

# %%
train_pivot_ii = train_pivot1.T

# %%
train_pivot_ii
# Out:
# reviews_username                                    00sab00  02dakota  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...      1.0       1.0
# 100:Complete First Season (blu-Ray)                     1.0       1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...      1.0       1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                  1.0       1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"           1.0       1.0
# ...                                                     ...       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...      1.0       1.0
# Weleda Everon Lip Balm                                  1.0       1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...      1.0       1.0
# Yes To Carrots Nourishing Body Wash                     1.0       1.0
# Yes To Grapefruit Rejuvenating Body Wash                1.0       1.0
#
# reviews_username                                    02deuce  0325home  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...      1.0       1.0
# 100:Complete First Season (blu-Ray)                     1.0       1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...      1.0       1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                  1.0       1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"           1.0       1.0
# ...                                                     ...       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...      1.0       1.0
# Weleda Everon Lip Balm                                  1.0       1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...      1.0       1.0
# Yes To Carrots Nourishing Body Wash                     1.0       1.0
# Yes To Grapefruit Rejuvenating Body Wash                1.0       1.0
#
# reviews_username                                    06stidriver  1.11E+24  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...          1.0       1.0
# 100:Complete First Season (blu-Ray)                         1.0       1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...          1.0       1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                      1.0       1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"               1.0       1.0
# ...                                                         ...       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...          1.0       1.0
# Weleda Everon Lip Balm                                      1.0       1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...          1.0       1.0
# Yes To Carrots Nourishing Body Wash                         1.0       1.0
# Yes To Grapefruit Rejuvenating Body Wash                    1.0       1.0
#
# reviews_username                                    1085  10ten  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...   1.0    1.0
# 100:Complete First Season (blu-Ray)                  1.0    1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...   1.0    1.0
# 2x Ultra Era with Oxi Booster, 50fl oz               1.0    1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"        1.0    1.0
# ...                                                  ...    ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...   1.0    1.0
# Weleda Everon Lip Balm                               1.0    1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...   1.0    1.0
# Yes To Carrots Nourishing Body Wash                  1.0    1.0
# Yes To Grapefruit Rejuvenating Body Wash             1.0    1.0
#
# reviews_username                                    11111111aaaaaaaaaaaaaaaaa  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...                        1.0
# 100:Complete First Season (blu-Ray)                                       1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...                        1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                                    1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"                             1.0
# ...                                                                       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...                        1.0
# Weleda Everon Lip Balm                                                    1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...                        1.0
# Yes To Carrots Nourishing Body Wash                                       1.0
# Yes To Grapefruit Rejuvenating Body Wash                                  1.0
#
# reviews_username                                    11677j  ...  zowie  \
# name                                                        ...
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...     1.0  ...    1.0
# 100:Complete First Season (blu-Ray)                    1.0  ...    1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...     1.0  ...    1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                 1.0  ...    1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"          1.0  ...    1.0
# ...                                                    ...  ...    ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...     1.0  ...    1.0
# Weleda Everon Lip Balm                                 1.0  ...    1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...     1.0  ...    1.0
# Yes To Carrots Nourishing Body Wash                    1.0  ...    1.0
# Yes To Grapefruit Rejuvenating Body Wash               1.0  ...    1.0
#
# reviews_username                                    zozo0o  zsazsa  zt313  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...     1.0     1.0    1.0
# 100:Complete First Season (blu-Ray)                    1.0     1.0    1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...     1.0     1.0    1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                 1.0     1.0    1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"          1.0     1.0    1.0
# ...                                                    ...     ...    ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...     1.0     1.0    1.0
# Weleda Everon Lip Balm                                 1.0     1.0    1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...     1.0     1.0    1.0
# Yes To Carrots Nourishing Body Wash                    1.0     1.0    1.0
# Yes To Grapefruit Rejuvenating Body Wash               1.0     1.0    1.0
#
# reviews_username                                    zubb  zuttle  zwithanx  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...   1.0     1.0       1.0
# 100:Complete First Season (blu-Ray)                  1.0     1.0       1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...   1.0     1.0       1.0
# 2x Ultra Era with Oxi Booster, 50fl oz               1.0     1.0       1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"        1.0     1.0       1.0
# ...                                                  ...     ...       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...   1.0     1.0       1.0
# Weleda Everon Lip Balm                               1.0     1.0       1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...   1.0     1.0       1.0
# Yes To Carrots Nourishing Body Wash                  1.0     1.0       1.0
# Yes To Grapefruit Rejuvenating Body Wash             1.0     1.0       1.0
#
# reviews_username                                    zxcsdfd  zyiah4  zzdiane
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...      1.0     1.0      1.0
# 100:Complete First Season (blu-Ray)                     1.0     1.0      1.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...      1.0     1.0      1.0
# 2x Ultra Era with Oxi Booster, 50fl oz                  1.0     1.0      1.0
# 42 Dual Drop Leaf Table with 2 Madrid Chairs"           1.0     1.0      1.0
# ...                                                     ...     ...      ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...      1.0     1.0      1.0
# Weleda Everon Lip Balm                                  1.0     1.0      1.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...      1.0     1.0      1.0
# Yes To Carrots Nourishing Body Wash                     1.0     1.0      1.0
# Yes To Grapefruit Rejuvenating Body Wash                1.0     1.0      1.0
#
# [254 rows x 18205 columns]

# %%
item_corr_matrix, normalized_item_df = cosine_similarity(train_pivot_ii)
item_corr_matrix.shape
# Out:
# (254, 254)

# %%
item_pred_rating = np.dot((train_pivot_ii.fillna(0)).T,item_corr_matrix)
item_pred_rating[item_pred_rating<0] = 0

# %%
item_pred_rating
# Out:
# array([[1.04268435, 0.82942606, 0.90407857, ..., 0.8340146 , 0.81433002,
#         0.79418324],
#        [1.02447686, 0.82044582, 0.89224956, ..., 0.75605699, 0.74593788,
#         0.77182255],
#        [1.03032533, 0.82731907, 0.89604918, ..., 0.7795106 , 0.76225108,
#         0.78034392],
#        ...,
#        [1.00512388, 0.6688738 , 0.87967635, ..., 0.59972721, 0.70334103,
#         0.70927094],
#        [1.00512388, 0.6688738 , 0.87967635, ..., 0.59972721, 0.70334103,
#         0.70927094],
#        [1.03749796, 0.8109133 , 0.90070908, ..., 0.81815776, 0.81746936,
#         0.78245846]])

# %%
#final rating for items
item_final_rating = np.multiply(item_pred_rating,train_pivot)

# %%
item_final_rating
# Out:
# name              0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. Fire File Chest  \
# reviews_username
# 00sab00                                                    1.042684
# 02dakota                                                   1.024477
# 02deuce                                                    1.030325
# 0325home                                                   1.005124
# 06stidriver                                                1.005124
# ...                                                             ...
# zuttle                                                     1.037404
# zwithanx                                                   1.005124
# zxcsdfd                                                    1.005124
# zyiah4                                                     1.005124
# zzdiane                                                    1.037498
#
# name              100:Complete First Season (blu-Ray)  \
# reviews_username
# 00sab00                                      0.829426
# 02dakota                                     0.820446
# 02deuce                                      0.827319
# 0325home                                     0.668874
# 06stidriver                                  0.668874
# ...                                               ...
# zuttle                                       0.821633
# zwithanx                                     0.668874
# zxcsdfd                                      0.668874
# zyiah4                                       0.668874
# zzdiane                                      0.810913
#
# name              2017-2018 Brownline174 Duraflex 14-Month Planner 8 1/2 X 11 Black  \
# reviews_username
# 00sab00                                                    0.904079
# 02dakota                                                   0.892250
# 02deuce                                                    0.896049
# 0325home                                                   0.879676
# 06stidriver                                                0.879676
# ...                                                             ...
# zuttle                                                     0.900648
# zwithanx                                                   0.879676
# zxcsdfd                                                    0.879676
# zyiah4                                                     0.879676
# zzdiane                                                    0.900709
#
# name              2x Ultra Era with Oxi Booster, 50fl oz  \
# reviews_username
# 00sab00                                         0.865297
# 02dakota                                        0.848678
# 02deuce                                         0.854016
# 0325home                                        0.831013
# 06stidriver                                     0.831013
# ...                                                  ...
# zuttle                                          0.860477
# zwithanx                                        0.831013
# zxcsdfd                                         0.831013
# zyiah4                                          0.831013
# zzdiane                                         0.860563
#
# name              42 Dual Drop Leaf Table with 2 Madrid Chairs"  \
# reviews_username
# 00sab00                                                1.257602
# 02dakota                                               1.146304
# 02deuce                                                1.148991
# 0325home                                               1.137414
# 06stidriver                                            1.137414
# ...                                                         ...
# zuttle                                                 1.152243
# zwithanx                                               1.137414
# zxcsdfd                                                1.137414
# zyiah4                                                 1.137414
# zzdiane                                                1.358154
#
# name              4C Grated Parmesan Cheese 100% Natural 8oz Shaker  \
# reviews_username
# 00sab00                                                    0.864404
# 02dakota                                                   0.847674
# 02deuce                                                    0.853048
# 0325home                                                   0.829892
# 06stidriver                                                0.829892
# ...                                                             ...
# zuttle                                                     0.859552
# zwithanx                                                   0.829892
# zxcsdfd                                                    0.829892
# zyiah4                                                     0.829892
# zzdiane                                                    0.859638
#
# name              5302050 15/16 FCT/HOSE ADAPTOR  \
# reviews_username
# 00sab00                                 0.932152
# 02dakota                                0.923788
# 02deuce                                 0.926475
# 0325home                                0.914898
# 06stidriver                             0.914898
# ...                                          ...
# zuttle                                  0.929727
# zwithanx                                0.914898
# zxcsdfd                                 0.914898
# zyiah4                                  0.914898
# zzdiane                                 0.929770
#
# name              Africa's Best No-Lye Dual Conditioning Relaxer System Super  \
# reviews_username
# 00sab00                                                    0.904079
# 02dakota                                                   0.892250
# 02deuce                                                    0.896049
# 0325home                                                   0.879676
# 06stidriver                                                0.879676
# ...                                                             ...
# zuttle                                                     0.900648
# zwithanx                                                   0.879676
# zxcsdfd                                                    0.879676
# zyiah4                                                     0.879676
# zzdiane                                                    0.900709
#
# name              Alberto VO5 Salon Series Smooth Plus Sleek Shampoo  \
# reviews_username
# 00sab00                                                    0.904079
# 02dakota                                                   0.892250
# 02deuce                                                    0.896049
# 0325home                                                   0.879676
# 06stidriver                                                0.879676
# ...                                                             ...
# zuttle                                                     0.900648
# zwithanx                                                   0.879676
# zxcsdfd                                                    0.879676
# zyiah4                                                     0.879676
# zzdiane                                                    0.900709
#
# name              Alex Cross (dvdvideo)  ...  Vicks Vaporub, Regular, 3.53oz  \
# reviews_username                         ...
# 00sab00                        0.776925  ...                        0.629687
# 02dakota                       0.739312  ...                        0.566040
# 02deuce                        0.748478  ...                        0.586484
# 0325home                       0.599313  ...                        0.527652
# 06stidriver                    0.599313  ...                        0.527652
# ...                                 ...  ...                             ...
# zuttle                         0.779304  ...                        0.624816
# zwithanx                       0.599313  ...                        0.527652
# zxcsdfd                        0.599313  ...                        0.527652
# zyiah4                         0.599313  ...                        0.527652
# zzdiane                        0.777873  ...                        0.611557
#
# name              Voortman Sugar Free Fudge Chocolate Chip Cookies  \
# reviews_username
# 00sab00                                                   0.904079
# 02dakota                                                  0.892250
# 02deuce                                                   0.896049
# 0325home                                                  0.879676
# 06stidriver                                               0.879676
# ...                                                            ...
# zuttle                                                    0.900648
# zwithanx                                                  0.879676
# zxcsdfd                                                   0.879676
# zyiah4                                                    0.879676
# zzdiane                                                   0.900709
#
# name              Wagan Smartac 80watt Inverter With Usb  \
# reviews_username
# 00sab00                                         0.948084
# 02dakota                                        0.999030
# 02deuce                                         0.987127
# 0325home                                        0.923927
# 06stidriver                                     0.923927
# ...                                                  ...
# zuttle                                          0.944688
# zwithanx                                        0.923927
# zxcsdfd                                         0.923927
# zyiah4                                          0.923927
# zzdiane                                         0.944749
#
# name              Walkers Stem Ginger Shortbread  \
# reviews_username
# 00sab00                                 0.932152
# 02dakota                                0.923788
# 02deuce                                 0.926475
# 0325home                                0.914898
# 06stidriver                             0.914898
# ...                                          ...
# zuttle                                  0.929727
# zwithanx                                0.914898
# zxcsdfd                                 0.914898
# zyiah4                                  0.914898
# zzdiane                                 0.929770
#
# name              Way Basics 3-Shelf Eco Narrow Bookcase Storage Shelf, Espresso - Formaldehyde Free - Lifetime Guarantee  \
# reviews_username
# 00sab00                                                    0.987044
# 02dakota                                                   0.998108
# 02deuce                                                    0.988945
# 0325home                                                   0.927441
# 06stidriver                                                0.927441
# ...                                                             ...
# zuttle                                                     0.953126
# zwithanx                                                   0.927441
# zxcsdfd                                                    0.927441
# zyiah4                                                     0.927441
# zzdiane                                                    1.012633
#
# name              WeatherTech 40647 14-15 Outlander Cargo Liners Behind 2nd Row, Black  \
# reviews_username
# 00sab00                                                    0.786945
# 02dakota                                                   0.760634
# 02deuce                                                    0.769085
# 0325home                                                   0.732668
# 06stidriver                                                0.732668
# ...                                                             ...
# zuttle                                                     0.779314
# zwithanx                                                   0.732668
# zxcsdfd                                                    0.732668
# zyiah4                                                     0.732668
# zzdiane                                                    0.779450
#
# name              Weleda Everon Lip Balm  \
# reviews_username
# 00sab00                         0.874076
# 02dakota                        0.858542
# 02deuce                         0.863532
# 0325home                        0.842030
# 06stidriver                     0.842030
# ...                                  ...
# zuttle                          0.869571
# zwithanx                        0.842030
# zxcsdfd                         0.842030
# zyiah4                          0.842030
# zzdiane                         0.869651
#
# name              Windex Original Glass Cleaner Refill 67.6oz (2 Liter)  \
# reviews_username
# 00sab00                                                    0.834015
# 02dakota                                                   0.756057
# 02deuce                                                    0.779511
# 0325home                                                   0.599727
# 06stidriver                                                0.599727
# ...                                                             ...
# zuttle                                                     0.812825
# zwithanx                                                   0.599727
# zxcsdfd                                                    0.599727
# zyiah4                                                     0.599727
# zzdiane                                                    0.818158
#
# name              Yes To Carrots Nourishing Body Wash  \
# reviews_username
# 00sab00                                      0.814330
# 02dakota                                     0.745938
# 02deuce                                      0.762251
# 0325home                                     0.703341
# 06stidriver                                  0.703341
# ...                                               ...
# zuttle                                       0.781995
# zwithanx                                     0.703341
# zxcsdfd                                      0.703341
# zyiah4                                       0.703341
# zzdiane                                      0.817469
#
# name              Yes To Grapefruit Rejuvenating Body Wash
# reviews_username
# 00sab00                                           0.794183
# 02dakota                                          0.771823
# 02deuce                                           0.780344
# 0325home                                          0.709271
# 06stidriver                                       0.709271
# ...                                                    ...
# zuttle                                            0.782245
# zwithanx                                          0.709271
# zxcsdfd                                           0.709271
# zyiah4                                            0.709271
# zzdiane                                           0.782458
#
# [18205 rows x 254 columns]

# %%
d_item = item_final_rating
d_item.loc['joshua'].sort_values(ascending=False)[:20]
# Out:
# name
# Pink Friday: Roman Reloaded Re-Up (w/dvd)                                                 55.168822
# Smead174 Recycled Letter Size Manila File Backs W/prong Fasteners, 2 Capacity, 100/box    55.168822
# Cheetos Crunchy Flamin' Hot Cheese Flavored Snacks                                        33.465287
# Red (special Edition) (dvdvideo)                                                          13.700189
# Dark Shadows (includes Digital Copy) (ultraviolet) (dvdvideo)                              8.680251
# Cantu Coconut Milk Shine Hold Mist - 8oz                                                   2.310821
# Newman's Own Organics Licorice Twist, Black 5oz                                            2.293461
# Sea Gull Lighting Six Light Bath Sconce/vanity - Brushed Nickel                            2.254708
# Naturtint Nutrideep Multiplier Protective Cream                                            2.245405
# The Seaweed Bath Co. Argan Conditioner, Smoothing Citrus                                   2.108364
# Chips Deluxe Soft 'n Chewy Cookies                                                         2.062174
# Diet Canada Dry Ginger Ale - 12pk/12 Fl Oz Cans                                            1.851911
# Home Health Hairever Shampoo                                                               1.830278
# Various - Country's Greatest Gospel:Gold Ed (cd)                                           1.770278
# Tostitos Bite Size Tortilla Chips                                                          1.752276
# Mill Creek Aloe Vera & Paba Lotion                                                         1.671250
# Chobani174 Strawberry On The Bottom Non-Fat Greek Yogurt - 5.3oz                           1.590353
# Colorganics Lipstick, Cayenne                                                              1.547864
# Nearly Natural 5.5' Bamboo W/decorative Planter                                            1.539846
# Newman's Own Balsamic Vinaigrette, 16.0oz                                                  1.538832
# Name: joshua, dtype: float64

# %%
# Copy the train dataset into dummy_train
dummy_train = train.copy()

# %%
dummy_train.head()
# Out:
#                          id   brand  \
# 15221  AVpf4oLxLJeJML43FcxC   Avery
# 21212  AVpfm8yiLJeJML43AYyu  Nexxus
# 14505  AVpf3VOfilAPnD_xjpun  Clorox
# 15266  AVpf4oLxLJeJML43FcxC   Avery
# 1413   AV1ZT7GLglJLPUi8IQLI   Suave
#
#                                               categories  \
# 15221  Office,Office Supplies,Office Organization,Bin...
# 21212  Personal Care,Hair Care,Styling Gel/Lotion,Bea...
# 14505  Household Essentials,Cleaning Supplies,Kitchen...
# 15266  Office,Office Supplies,Office Organization,Bin...
# 1413   Personal Care,Hair Care,Conditioner,Conditione...
#
#                  manufacturer  \
# 15221          Avery Dennison
# 21212  Nexxus Beauty Products
# 14505                  Clorox
# 15266          Avery Dennison
# 1413                 UNILEVER
#
#                                                     name  \
# 15221  Avery174 Ready Index Contemporary Table Of Con...
# 21212          Nexxus Exxtra Gel Style Creation Sculptor
# 14505  Clorox Disinfecting Wipes Value Pack Scented 1...
# 15266  Avery174 Ready Index Contemporary Table Of Con...
# 1413         Suave Professionals Hair Conditioner, Sleek
#
#                    reviews_date reviews_didPurchase reviews_doRecommend  \
# 15221  2009-10-08T00:00:00.000Z               False                True
# 21212  2015-09-04T00:00:00.000Z               False               False
# 14505  2015-02-13T00:00:00.000Z               False                True
# 15266  2010-02-11T00:00:00.000Z               False                True
# 1413   2014-02-11T00:00:00.000Z               False                True
#
#        reviews_rating                                       reviews_text  \
# 15221               5  These worked great for an ongoing project of m...
# 21212               1  I've been using this gel for as long as I can ...
# 14505               5  I like how the wipes cleans the surface and ki...
# 15266               5  these tabs are very professional looking and m...
# 1413                5  I switched to Suave Sleek Shampoo Conditioner ...
#
#                  reviews_title reviews_userCity reviews_userProvince  \
# 15221            Great Product              NaN                  NaN
# 21212              New formula              NaN                  NaN
# 14505        The best cleaner!              NaN                  NaN
# 15266  these tabs are very ...              NaN                  NaN
# 1413    Just as good as Matrix              NaN                  NaN
#
#       reviews_username user_sentiment
# 15221             dpat       Positive
# 21212         kristink       Negative
# 14505        mamaw1955       Positive
# 15266           rademc       Positive
# 1413          mcfarr56       Positive

# %% [markdown]
# ## Evaluation of Item and Item

# %%
common_item = test[test.name.isin(train.name)]

# %%
common_item
# Out:
#                          id     brand  \
# 19154  AVpfJP1C1cnluZ0-e3Xy    Clorox
# 22871  AVpfov9TLJeJML43A7B0  Bisquick
# 11830  AVpf3VOfilAPnD_xjpun    Clorox
# 707    AV1YGDqsGV-KLJ3adc-O    Windex
# 20513  AVpfJP1C1cnluZ0-e3Xy    Clorox
# ...                     ...       ...
# 28158  AVpfRTh1ilAPnD_xYic2    Disney
# 7350   AVpf3VOfilAPnD_xjpun    Clorox
# 16974  AVpf9pzn1cnluZ0-uNTM  Lundberg
# 19418  AVpfJP1C1cnluZ0-e3Xy    Clorox
# 8667   AVpf3VOfilAPnD_xjpun    Clorox
#
#                                               categories  \
# 19154  Household Chemicals,Household Cleaners,Bath & ...
# 22871  Food & Beverage,Baking & Cooking Essentials,Ba...
# 11830  Household Essentials,Cleaning Supplies,Kitchen...
# 707    Household Essentials,Cleaning Supplies,Glass C...
# 20513  Household Chemicals,Household Cleaners,Bath & ...
# ...                                                  ...
# 28158  Movies, Music & Books,Movies,Kids' & Family,Wa...
# 7350   Household Essentials,Cleaning Supplies,Kitchen...
# 16974  Food,Packaged Foods,Packaged Grains,Rice,Brown...
# 19418  Household Chemicals,Household Cleaners,Bath & ...
# 8667   Household Essentials,Cleaning Supplies,Kitchen...
#
#                     manufacturer  \
# 19154             AmazonUs/CLOO7
# 22871  GENERAL MILLS SALES, INC.
# 11830                     Clorox
# 707                       Windex
# 20513             AmazonUs/CLOO7
# ...                          ...
# 28158                Walt Disney
# 7350                      Clorox
# 16974      Lundberg Family Farms
# 19418             AmazonUs/CLOO7
# 8667                      Clorox
#
#                                                     name  \
# 19154               Clorox Disinfecting Bathroom Cleaner
# 22871    Bisquick Original Pancake And Baking Mix - 40oz
# 11830  Clorox Disinfecting Wipes Value Pack Scented 1...
# 707    Windex Original Glass Cleaner Refill 67.6oz (2...
# 20513               Clorox Disinfecting Bathroom Cleaner
# ...                                                  ...
# 28158  Planes: Fire Rescue (2 Discs) (includes Digita...
# 7350   Clorox Disinfecting Wipes Value Pack Scented 1...
# 16974                         Lundberg Wehani Rice, 25lb
# 19418               Clorox Disinfecting Bathroom Cleaner
# 8667   Clorox Disinfecting Wipes Value Pack Scented 1...
#
#                    reviews_date reviews_didPurchase reviews_doRecommend  \
# 19154  2014-12-30T00:00:00.000Z               False                True
# 22871  2012-07-25T00:00:00.000Z               False                True
# 11830  2014-12-05T00:00:00.000Z               False                True
# 707    2015-08-18T00:00:00.000Z               False               False
# 20513  2014-04-07T12:05:20.000Z                 NaN                 NaN
# ...                         ...                 ...                 ...
# 28158  2014-11-07T00:00:00.000Z                 NaN                True
# 7350   2015-01-28T00:00:00.000Z               False                True
# 16974  2015-09-17T00:00:00.000Z                 NaN                 NaN
# 19418  2012-01-26T00:00:00.000Z               False                True
# 8667   2012-01-26T14:05:59.000Z                 NaN                True
#
#        reviews_rating                                       reviews_text  \
# 19154               5  Very powerful, great at removing stains, and s...
# 22871               5  you can do sooooo much with this product..bisc...
# 11830               5  I love the lemon fresh smell it leaves. I know...
# 707                 1  Windex used to be the best but whatever they h...
# 20513               5  I have two sons and they make a mess in their ...
# ...               ...                                                ...
# 28158               5  Great family movie. My kids loved it. Goes goo...
# 7350                4  Good product and very convenient to have aroun...
# 16974               5  THIS RICE IS THE ONLY ONE I EAT AT HOME. SO NU...
# 19418               5  i use the clorox wipes for everything. they ar...
# 8667                5  Quicks and Easy. Great smell. House smells cle...
#
#                         reviews_title reviews_userCity reviews_userProvince  \
# 19154                    Clorox Rocks              NaN                  NaN
# 22871         Alot of a good thing!!!              NaN                  NaN
# 11830      Keep Cancer Home Germ Free              NaN                  NaN
# 707    no longer a good glass cleaner              NaN                  NaN
# 20513                Great In Showers              NaN                  NaN
# ...                               ...              ...                  ...
# 28158                     great movie              NaN                  NaN
# 7350                       convenient              NaN                  NaN
# 16974                      Five Stars              NaN                  NaN
# 19418              great for anything              NaN                  NaN
# 8667                  Quick And Easy!          Lincoln                  NaN
#
#          reviews_username user_sentiment
# 19154              briley       Positive
# 22871           foxfire61       Positive
# 11830             margies       Positive
# 707                   mel       Negative
# 20513  jillybeansoccermom       Negative
# ...                   ...            ...
# 28158                tony       Positive
# 7350          heggemister       Positive
# 16974        byindubstylo       Negative
# 19418             nack101       Positive
# 8667                lacey       Positive
#
# [8983 rows x 15 columns]

# %%
common_item_pivot = common_item.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating').T

common_item_pivot.shape
# Out:
# (206, 8379)

# %%
item_corr_df = pd.DataFrame(item_corr_matrix)
#item_corr_df

# %%
item_corr_df['name'] = normalized_item_df.index
item_corr_df.set_index('name',inplace=True)
#item_corr_df

# %%
list_items = common_item.name.tolist()
item_corr_df.columns = normalized_item_df.index.tolist()
#item_corr_df

# %%
#list_items

# %%
item_corr_df1 = item_corr_df[item_corr_df.index.isin(list_items)]
#item_corr_df1

# %%
item_corr_df2 = item_corr_df1.T[item_corr_df1.T.index.isin(list_items)]
item_corr_df3 = item_corr_df2.T
#item_corr_df3

# %%
item_corr_df3[item_corr_df3<0] = 0
common_item_pred_ratings = np.dot(item_corr_df3,common_item_pivot.fillna(0))
common_item_pred_ratings.shape
# Out:
# (206, 8379)

# %%
test_items = common_item.copy()

# %%
test_item_tb = test_items.pivot_table(index='reviews_username',
                            columns='name',
                            values='reviews_rating').T.fillna(0)
final_item_ratings = np.multiply(common_item_pred_ratings,test_item_tb)
final_item_ratings
# Out:
# reviews_username                                    00dog3  01impala  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...     0.0       0.0
# 100:Complete First Season (blu-Ray)                    0.0       0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...     0.0       0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                 0.0       0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker      0.0       0.0
# ...                                                    ...       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...     0.0       0.0
# Weleda Everon Lip Balm                                 0.0       0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...     0.0       0.0
# Yes To Carrots Nourishing Body Wash                    0.0       0.0
# Yes To Grapefruit Rejuvenating Body Wash               0.0       0.0
#
# reviews_username                                    08dallas  09mommy11  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...       0.0        0.0
# 100:Complete First Season (blu-Ray)                     25.0        0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...       0.0        0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                   0.0        0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker        0.0        0.0
# ...                                                      ...        ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...       0.0        0.0
# Weleda Everon Lip Balm                                   0.0        0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...       0.0        0.0
# Yes To Carrots Nourishing Body Wash                      0.0        0.0
# Yes To Grapefruit Rejuvenating Body Wash                 0.0        0.0
#
# reviews_username                                    1143mom  1234  123charlie  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...      0.0   0.0         0.0
# 100:Complete First Season (blu-Ray)                     0.0   0.0         0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...      0.0   0.0         0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                  0.0   0.0         0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker       0.0   0.0         0.0
# ...                                                     ...   ...         ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...      0.0   0.0         0.0
# Weleda Everon Lip Balm                                  0.0   0.0         0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...      9.0   0.0         0.0
# Yes To Carrots Nourishing Body Wash                     0.0   0.0         0.0
# Yes To Grapefruit Rejuvenating Body Wash                0.0   0.0         0.0
#
# reviews_username                                    123numbers  12cass12  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...         0.0       0.0
# 100:Complete First Season (blu-Ray)                        0.0       0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...         0.0       0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                     0.0       0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker          0.0       0.0
# ...                                                        ...       ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...         0.0       0.0
# Weleda Everon Lip Balm                                     0.0       0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...         0.0       0.0
# Yes To Carrots Nourishing Body Wash                        0.0       0.0
# Yes To Grapefruit Rejuvenating Body Wash                   0.0       0.0
#
# reviews_username                                    132457  ...  zombiedad80  \
# name                                                        ...
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...     0.0  ...          0.0
# 100:Complete First Season (blu-Ray)                    0.0  ...          0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...     0.0  ...          0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                 0.0  ...          0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker      0.0  ...          0.0
# ...                                                    ...  ...          ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...     0.0  ...          0.0
# Weleda Everon Lip Balm                                 0.0  ...          0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...     0.0  ...          0.0
# Yes To Carrots Nourishing Body Wash                    0.0  ...          0.0
# Yes To Grapefruit Rejuvenating Body Wash               0.0  ...          0.0
#
# reviews_username                                    zombiegirl22  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...           0.0
# 100:Complete First Season (blu-Ray)                          0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...           0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                       0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker            0.0
# ...                                                          ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...           0.0
# Weleda Everon Lip Balm                                       0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...           0.0
# Yes To Carrots Nourishing Body Wash                          0.0
# Yes To Grapefruit Rejuvenating Body Wash                     0.0
#
# reviews_username                                    zombiekiller  zoney86  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...           0.0      0.0
# 100:Complete First Season (blu-Ray)                          0.0      0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...           0.0      0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                       0.0      0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker            0.0      0.0
# ...                                                          ...      ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...           0.0      0.0
# Weleda Everon Lip Balm                                       0.0      0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...           0.0      0.0
# Yes To Carrots Nourishing Body Wash                          0.0      0.0
# Yes To Grapefruit Rejuvenating Body Wash                     0.0      0.0
#
# reviews_username                                    zookeeper  zpalma  zsarah  \
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...        0.0     0.0     0.0
# 100:Complete First Season (blu-Ray)                       0.0     0.0     0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...        0.0     0.0     0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                    0.0     0.0     0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker         0.0     0.0     0.0
# ...                                                       ...     ...     ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...        0.0     0.0     0.0
# Weleda Everon Lip Balm                                    0.0     0.0     0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...        0.0     0.0     0.0
# Yes To Carrots Nourishing Body Wash                       0.0     0.0     0.0
# Yes To Grapefruit Rejuvenating Body Wash                  0.0     0.0     0.0
#
# reviews_username                                    zulaa118  zxjki  zzz1127
# name
# 0.6 Cu. Ft. Letter A4 Size Waterproof 30 Min. F...       0.0    0.0      0.0
# 100:Complete First Season (blu-Ray)                      0.0    0.0      0.0
# 2017-2018 Brownline174 Duraflex 14-Month Planne...       0.0    0.0      0.0
# 2x Ultra Era with Oxi Booster, 50fl oz                   0.0    0.0      0.0
# 4C Grated Parmesan Cheese 100% Natural 8oz Shaker        0.0    0.0      0.0
# ...                                                      ...    ...      ...
# WeatherTech 40647 14-15 Outlander Cargo Liners ...       0.0    0.0      0.0
# Weleda Everon Lip Balm                                   0.0    0.0      0.0
# Windex Original Glass Cleaner Refill 67.6oz (2 ...       0.0    0.0      0.0
# Yes To Carrots Nourishing Body Wash                      0.0    0.0      0.0
# Yes To Grapefruit Rejuvenating Body Wash                 0.0    0.0      0.0
#
# [206 rows x 8379 columns]

# %%
X  = final_item_ratings.copy() 
X = X[X>0]

scaler = MinMaxScaler(feature_range=(1, 5))
print(scaler.fit(X))
y = (scaler.transform(X))

print(y)
y.shape
# Out:
# MinMaxScaler(feature_range=(1, 5))
# [[nan nan nan ... nan nan nan]
#  [nan nan  1. ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# (206, 8379)

# %%
# Finding total non-NaN value
total_non_nan = np.count_nonzero(~np.isnan(y))

# %% [markdown]
# ## Calculate RMSE

# %%
rmse = (sum(sum((common_item_pivot -  y )**2))/total_non_nan)**0.5
print(rmse)
# Out:
# 3.5545409495089935

# %% [markdown]
# <font color=Blue>
#
# #### <u> SUMMARY:</u>
#
# 1. RMSE for USER-USER is 1.87 and RMSE for ITEM-ITEM is 3.55. Lesser the RMSE better the model. Hence User-User
# recommendation system is suitable recommendataion systems for this dataset
# 2. User-User Recommedation is loaded into available in user_final_rating.pkl
# </font>

# %% [markdown]
# <font color=Blue>
#
# #### <u> Notes:</u>
#
# 1. Model.py: This file has the Top 20 Products and Top 5 Products recommended based on sentiment
# 2. Pickle files: Are avaialble in Pickle folder
# 3. Heroku URL :
# </font>
